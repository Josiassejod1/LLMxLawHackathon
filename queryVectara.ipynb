# %%
import requests

# %%
query_from_user = "I am a landlord. Can I give my periodic tenant a 30 day notice to move out ? "

# %% [markdown]
# This is getting the samantic most relevant text chunks based on our query from the knowledge base (Vector Data bases)

# %%
headers = {
    'Authorization': 'Bearer eyJraWQiOiJvUnVNVmNrXC9DRFN2R2RDa2ViVEc2SVIwM0NCbmtlbnRISjFkNGFEZUZpUT0iLCJhbGciOiJSUzI1NiJ9.....BzLAGRqK5xkk33M-ZX6B5msBUlZQDnIwVhDqZ8dQJaFvbsRLj05A-5NawDu8l7gQUlTIMpaUYevZf3ox3ss9e0pIUibDFGqdEgQK_2q541uIXa1yaLcGoOYEvuqMwrvplzOa9-DaAh9iqzL7HCMWPKbuWuLPdJDfSzc0xK91PsOdJsRnEWiHdDzVpSJGKfEVleHgHezKNY1RU-F7QxneWJSq96VvmKIjLvql21W-NugpeMiYO1aOcjR2lW-mXgbX6by5WstTpddPSjl8898HUuCZ_a2wMALVlI2-wX9W5dvTC3yB1LHzhmv-_1jS5Xaj6iSvXEKYvzIbyOeQ3xEXsw' ,
    'customer-id': '2531807925',
    'Content-Type': 'application/x-www-form-urlencoded',
}

data = '{"query": [    {      "query": "{query_from_user}",      "queryContext": "",      "start": 0,      "numResults": 10,      "contextConfig": {        "charsBefore": 0,        "charsAfter": 0,        "sentencesBefore": 2,        "sentencesAfter": 2,        "startTag": "%START_SNIPPET%",        "endTag": "%END_SNIPPET%"      },      "corpusKey": [        {          "customerId": 2531807925,          "corpusId": 3,          "semantics": 0,          "metadataFilter": "doc.id = \'California-Tenants-Guide.pdf\'",          "lexicalInterpolationConfig": {            "lambda": 0.025          },          "dim": []        }      ],      "summary": [        {          "debug": false,          "maxSummarizedResults": 5,          "responseLang": "eng",          "summarizerPromptName": "vectara-summary-ext-v1.2.0",          "factualConsistencyScore": true        }      ]    }  ]}END        '

response = requests.post('https://api.vectara.io:443/v1/stream-query', headers=headers, data=data)

# %%
response.content

print(response.content)
# Out:
# b'{"result":{"batchQueryResponse":{"responseSet":[{"response":[],"status":[],"document":[],"summary":[{"text":"","lang":"","prompt":"","chat":null,"factualConsistency":null,"done":false,"status":[],"futureId":2}],"futureId":1}],"status":[],"metrics":null},"responseSet":null,"summary":null,"status":[]}}\n{"result":{"batchQueryResponse":null,"responseSet":{"response":[{"text":"If you still do not understand, discuss the agreement with an attorney,\\nlegal aid organization, tenant-landlord program, or housing clinic before signing it. Key terms\\n     The written rental agreement should contain key terms, such as the following:\\n\xe2\x80\xa2  The names of the landlord and the tenant. %START_SNIPPET%\xe2\x80\xa2  The address of the rental unit.%END_SNIPPET% \xe2\x80\xa2  The amount of the rent. \xe2\x80\xa2  When the rent is due, to whom it is to be paid, and where it is to be paid.","score":0.6589568,"metadata":[{"name":"page","value":"30"},{"name":"title","value":"WHAT THE RENTAL AGREEMENT SHOULD INCLUDE"},{"name":"breadcrumb","value":"[\\"WHEN YOU HAVE DECIDED TO RENT\\"]"},{"name":"lang","value":"eng"},{"name":"section","value":"31"},{"name":"offset","value":"2019"},{"name":"len","value":"34"}],"documentIndex":0,"corpusKey":{"customerId":0,"corpusId":3,"semantics":"DEFAULT","dim":[],"metadataFilter":"","lexicalInterpolationConfig":null},"resultOffset":311,"resultLength":34},{"text":"fixed term rental agreement\xe2\x80\x94A rental agreement between the landlord and tenant\\nusually in writing, that establishes all the terms of the agreement and that lasts for a\\npredetermined length of time with defined start and end dates (for example, six months\\nor one year). Compare to periodic rental agreement. %START_SNIPPET%guest\xe2\x80\x94a person who does not have the rights of a tenant, such as a person who\\nstays in a transient hotel for fewer than seven days or someone staying at a rental unit at\\nthe invitation of the tenant.%END_SNIPPET% habitable\xe2\x80\x94a rental unit that is fit for human beings to live in. A rental unit that\\nsubstantially complies with building and safety code standards that materially affect\\ntenants\xe2\x80\x99 health and safety is said to be \xe2\x80\x9chabitable.\xe2\x80\x9d","score":0.6557592,"metadata":[{"name":"page","value":"114"},{"name":"title","value":"GLOSSARY"},{"name":"lang","value":"eng"},{"name":"section","value":"137"},{"name":"offset","value":"9737"},{"name":"len","value":"199"}],"documentIndex":0,"corpusKey":{"customerId":0,"corpusId":3,"semantics":"DEFAULT","dim":[],"metadataFilter":"","lexicalInterpolationConfig":null},"resultOffset":322,"resultLength":199},{"text":"In these situations, the landlord\xe2\x80\x99s action may be considered retaliatory because the\\nlandlord is punishing the tenant for the tenant\xe2\x80\x99s exercise of a legal right. The law offers\\ntenants protection from retaliatory eviction and other retaliatory acts.444\\n    If a landlord tries to evict a tenant within six months after the tenant has exercised\\n certain rights, the law assumes the eviction is retaliatory.445 The following are examples of\\nrights that the tenant may lawfully exercise:\\n102\\n \xe2\x80\xa2    Using the repair and deduct remedy or telling the landlord that the tenant will use the\\n         repair and deduct remedy. %START_SNIPPET%\xe2\x80\xa2    Complaining about the condition of the rental unit to the landlord, or to an\\n        appropriate public agency (such as local code enforcement) after giving the landlord\\nnotice.%END_SNIPPET% \xe2\x80\xa2    Filing a lawsuit or beginning arbitration based on the condition of the rental unit. \xe2\x80\xa2    Causing an appropriate public agency to inspect the rental unit or to issue a citation\\n        to the landlord.","score":0.65425515,"metadata":[{"name":"page","value":"107"},{"name":"title","value":"A word about bankruptcy"},{"name":"breadcrumb","value":"[\\"TERMINATIONS AND EVICTIONS\\"]"},{"name":"lang","value":"eng"},{"na ...

# %%
GROC_API_KEY = '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'

GROC_API_KEY = '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'

# %%
import os
os.environ["GROQ_API_KEY"] = GROC_API_KEY

# %%
from groq import Groq


# Correct the environment variable name and use quotes
client = Groq(
    api_key=os.environ.get(GROC_API_KEY),
)

# %%
def augment_prompt(query: str):

    # get the text from the results
    source_knowledge = response.content
    # feed into an augmented prompt
    augmented_prompt = f"""Using the contexts below, answer the query.

    Contexts:
    {source_knowledge}

    Query: {query}"""
    return augmented_prompt

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": augment_prompt(query_from_user),
        }
    ],
    model="mixtral-8x7b-32768",
)

print(chat_completion.choices[0].message.content)
# Out:
# Based on the provided context, it is not explicitly stated if you can give your periodic tenant a 30-day notice to move out. However, it is mentioned that the landlord can terminate a periodic tenancy with proper notice as required by law. It's recommended to consult your state and local laws regarding termination and notice requirements for periodic tenancies. In California, for example, a landlord must provide a 30-day written notice to terminate a periodic tenancy.
